# %%
#TODO: Write the functions for arithmatic operations here
#These functions should cover Task 2

def add(a,b):
    return a+b

def subtract(a,b):
    return a-b

def multiply(a,b):
    return a*b

def divide(a,b):
    return a/b

def power(a,b):
    return a**b

def remainder(a,b):
    return a%b

def exit():
    return False 

#-------------------------------------
#TODO: Write the select_op(choice) function here
#This function sould cover Task 1 (Section 2) and Task 3

def select_op(choice):
    
    a = float(input("Enter First Number: "))
    b = float(input("Enter Second Number: "))
    
    if (choice == '$'):
        a = 0
        b = 0
        result = 0
        print("Done with Reset")
        choice = input("Enter Choice (+, -, *, /, ^, %, #, $)")
        print(choice)

#    if (choice == '#'):
#        print("Done. Terminating")
#        break
    
    
    #compare the input of the user before perform the calculation
    if (choice == '+'):
        result = add(a,b)

    if (choice == '-'):
        result = subtract(a,b)
        
    if (choice == '*'):
        result = multiply(a,b)
        
    if (choice == '/'):
        result = divide(a,b)

    if (choice == '^'):
        result = power(a,b)
         
    if (choice == '%'):
        result = remainder(a,b)
        if (result == 0):
            result = "None"        
    else:
        print("Unrecognized Operation")


    
#    if a != float:
#        print("Not a valid number")

    print(a, choice, b, "=", result)
    



#End the select_op(choice) function here
#-------------------------------------
#This is the main loop. It covers Task 1 (Section 1)
#YOU DO NOT NEED TO CHANGE ANYTHING BELOW THIS LINE
while True:
  print("Select operation.")
  print("1.Add      : + ")
  print("2.Subtract : - ")
  print("3.Multiply : * ")
  print("4.Divide   : / ")
  print("5.Power    : ^ ")
  print("6.Remainder: % ")
  print("7.Terminate: # ")
  print("8.Reset    : $ ")
  

  # take input from the user
  choice = input("Enter choice(+,-,*,/,^,%,#,$): ")
  print(choice)
  if(select_op(choice) == -1):
    #program ends here
    print("Done. Terminating")
    exit()
# Out:
# Select operation.
# 1.Add      : +
# 2.Subtract : -
# 3.Multiply : *
# 4.Divide   : /
# 5.Power    : ^
# 6.Remainder: %
# 7.Terminate: #
# 8.Reset    : $
# Enter choice(+,-,*,/,^,%,#,$): +
# +
# Enter First Number: 65
# Enter Second Number: 31
# Unrecognized Operation
# 65.0 + 31.0 = 96.0
# Select operation.
# 1.Add      : +
# 2.Subtract : -
# 3.Multiply : *
# 4.Divide   : /
# 5.Power    : ^
# 6.Remainder: %
# 7.Terminate: #
# 8.Reset    : $
# Enter choice(+,-,*,/,^,%,#,$): 89
# 89
# Enter First Number: 3
# Enter Second Number: 4
# Unrecognized Operation
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[17], line 99
#      97 choice = input("Enter choice(+,-,*,/,^,%,#,$): ")
#      98 print(choice)
# ---> 99 if(select_op(choice) == -1):
#     100   #program ends here
#     101   print("Done. Terminating")
#     102   exit()
#
# Cell In[17], line 75, in select_op(choice)
#      68         print("Unrecognized Operation")
#      72 #    if a != float:
#      73 #        print("Not a valid number")
# ---> 75     print(a, choice, b, "=", result)
#
# UnboundLocalError: local variable 'result' referenced before assignment
